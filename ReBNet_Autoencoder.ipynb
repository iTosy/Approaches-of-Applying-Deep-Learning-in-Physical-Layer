# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib

import tensorflow as tf
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Convolution2D, Activation, Flatten, MaxPooling2D,Input,Dropout,GlobalAveragePooling2D
from keras import backend as K
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.layers import Layer
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.layers import BatchNormalization
from tensorflow.python.framework import ops

# %%
def binarize(x):
    '''Element-wise rounding to the closest integer with full gradient propagation.
    A trick from [Sergey Ioffe](http://stackoverflow.com/a/36480182)
    '''
    clipped = K.clip(x,-1,1)
    rounded = K.sign(clipped)
    return clipped + K.stop_gradient(rounded - clipped)

# %%
class Residual_sign(Layer):
    def __init__(self, levels=1,**kwargs):
        self.levels=levels
        super(Residual_sign, self).__init__(**kwargs)
    def build(self, input_shape):
        ars=np.arange(self.levels)+1.0
        ars=ars[::-1]
        means=ars/np.sum(ars)
        self.means=[K.variable(m) for m in means]
        self._trainable_weights=self.means
    def call(self, x, mask=None):
        resid = x
        out_bin=0
        for l in range(self.levels):
            out=binarize(resid)*K.abs(self.means[l])
            out_bin=out_bin+out
            resid=resid-out
        return out_bin

    def get_output_shape_for(self,input_shape):
        return input_shape
    def compute_output_shape(self,input_shape):
		    return input_shape
    def set_means(self,X):
        means=np.zeros((self.levels))
        means[0]=1
        resid=np.clip(X,-1,1)
        approx=0
        for l in range(self.levels):
            m=np.mean(np.absolute(resid))
            out=np.sign(resid)*m
            approx=approx+out
            resid=resid-out
            means[l]=m
            err=np.mean((approx-np.clip(X,-1,1))**2)

        means=means/np.sum(means)
        sess=K.get_session()
        sess.run(self.means.assign(means))

# %%
class binary_conv(Layer):
	def __init__(self,nfilters,ch_in,k,padding,strides=(1,1),**kwargs):
		self.nfilters=nfilters
		self.ch_in=ch_in
		self.k=k
		self.padding=padding
		self.strides=strides
		super(binary_conv,self).__init__(**kwargs)
	def build(self, input_shape):
		stdv=1/np.sqrt(self.k*self.k*self.ch_in)
		w = np.random.normal(loc=0.0, scale=stdv,size=[self.k,self.k,self.ch_in,self.nfilters]).astype(np.float32)
		if keras.backend._backend=="mxnet":
			w=w.transpose(3,2,0,1)
		self.w=K.variable(w)
		self.gamma=K.variable(1.0)
		self.trainable_weights=[self.w,self.gamma]


	def call(self, x,mask=None):
		constraint_gamma=K.abs(self.gamma)#K.clip(self.gamma,0.01,10)
		self.clamped_w=constraint_gamma*binarize(self.w)
		if keras.__version__[0]=='2':
			self.out=K.conv2d(x, kernel=self.clamped_w, padding=self.padding,strides=self.strides )
		if keras.__version__[0]=='1':
			self.out=K.conv2d(x,self.clamped_w,border_mode=self.padding,strides=self.strides)
		self.output_dim=self.out.get_shape()
		return self.out
	def  get_output_shape_for(self,input_shape):
		return (input_shape[0], self.output_dim[1],self.output_dim[2],self.output_dim[3])
	def compute_output_shape(self,input_shape):
		return (input_shape[0], self.output_dim[1],self.output_dim[2],self.output_dim[3])

# %%
class binary_dense(Layer):
	def __init__(self,n_in,n_out,**kwargs):
		self.n_in=n_in
		self.n_out=n_out
		super(binary_dense,self).__init__(**kwargs)
	def build(self, input_shape):
		stdv=1/np.sqrt(self.n_in)
		w = np.random.normal(loc=0.0, scale=stdv,size=[self.n_in,self.n_out]).astype(np.float32)
		self.w=K.variable(w)
		self.gamma=K.variable(1.0)
		self._trainable_weights=[self.w,self.gamma]

	def call(self, x,mask=None):
		constraint_gamma=K.abs(self.gamma)#K.clip(self.gamma,0.01,10)
		self.clamped_w=constraint_gamma*binarize(self.w)
		self.out=K.dot(x,self.clamped_w)
		return self.out
	def  get_output_shape_for(self,input_shape):
		return (input_shape[0], self.n_out)
	def compute_output_shape(self,input_shape):
		return (input_shape[0], self.n_out)

# %%
from keras.callbacks import ModelCheckpoint


bers = []

#Creating one-hot vector training dataset corresponding to binary message

Nt = 10000                                      #No. of messages
k = 3                                           #block size
M = 2**k                                        #one-hot vector size
label = np.random.randint(M,size=Nt)
data = []
for i in label:
  temp = np.zeros(M)
  temp[i] = 1
  data.append(temp)
data = np.array(data)                           #training dataset

#Creating Validation dataset

N_val = 1500
val_label = np.random.randint(M,size=N_val)
val_data = []
for i in val_label:
  temp = np.zeros(M)
  temp[i] = 1
  val_data.append(temp)
val_data = np.array(val_data)

#Creating testing dataset

N = 50000
test_label = np.random.randint(M,size=N)
test_data = []

for i in test_label:
  temp = np.zeros(M)
  temp[i] = 1
  test_data.append(temp)

test_data = np.array(test_data)

#Create the corresponding binary model

for re in range(1,4):                 #residual levels M = 1,2,3
  BER = []

  #the model layers

  input = Input(shape=(8,))
  enco1 = binary_dense(n_in=8,n_out=8)(input)
  encor = Residual_sign(levels=re)(enco1)
  enco2 = binary_dense(n_in=8,n_out=7)(encor)

  norm = BatchNormalization(axis=-1, momentum=0.1, epsilon=1e-4)(enco2)

  EbNo_train = 10 ** (0.7)
  enco3 = keras.layers.GaussianNoise(np.sqrt(1/(2*(3/7)*EbNo_train)))(norm)     #train for SNR = 7 db

  deco1 = binary_dense(n_in=7,n_out=8)(enco3)
  decor = Residual_sign(levels=re)(deco1)
  deco2 = binary_dense(n_in=8,n_out=8)(decor)
  last = Activation('softmax')(deco2)

  opt = keras.optimizers.Adam(learning_rate=0.01,decay=1e-6)
  model = Model(input, last)
  model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

  model.fit(data, data,epochs=25,batch_size=300,validation_data=(val_data, val_data), callbacks=[ModelCheckpoint(save_best_only=True, filepath=str(re))])
  model.load_weights(str(re))

  #Encoder model
  encoder = Model(input, norm)

  #Receiver model
  encoded_input = Input(shape=(7,))

  decor = model.layers[-4](encoded_input)
  deco2 = model.layers[-3](decor)
  deco1 = model.layers[-2](deco2)
  deco = model.layers[-1](deco1)
  decoder = Model(encoded_input, deco)

  #Testing on SNR range

  SNRs = np.arange(-4,10.5,0.5)
  for snr in SNRs:
    EbNo=10.0**(snr/10.0)
    noise_std = np.sqrt(1/(2*(3/7)*EbNo))
    noise_mean = 0
    no_errors = 0
    noise = np.random.normal(0,noise_std,(N,7))
    encoded_signal = encoder.predict(test_data)
    final_signal = encoded_signal + noise
    pred_final_signal =  decoder.predict(final_signal)
    pred_output = np.argmax(pred_final_signal,axis=1)
    no_errors = (pred_output != test_label)
    no_errors =  no_errors.astype(int).sum()
    BER.append(no_errors / N)
  bers.append(BER)
# Out:
# Epoch 1/25
# 34/34 [==============================] - 3s 59ms/step - loss: 2.0147 - accuracy: 0.3948 - val_loss: 0.8745 - val_accuracy: 0.6080
# Epoch 2/25
# 34/34 [==============================] - 2s 49ms/step - loss: 0.6636 - accuracy: 0.7625 - val_loss: 0.6652 - val_accuracy: 0.7513
# Epoch 3/25
# 34/34 [==============================] - 41s 1s/step - loss: 0.6065 - accuracy: 0.7650 - val_loss: 0.2423 - val_accuracy: 1.0000
# Epoch 4/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.4366 - accuracy: 0.8525 - val_loss: 0.3124 - val_accuracy: 0.8753
# Epoch 5/25
# 34/34 [==============================] - 2s 49ms/step - loss: 0.3322 - accuracy: 0.8740 - val_loss: 0.1663 - val_accuracy: 1.0000
# Epoch 6/25
# 34/34 [==============================] - 2s 49ms/step - loss: 0.1861 - accuracy: 0.9389 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 7/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.1782 - accuracy: 0.9223 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 8/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.1332 - accuracy: 0.9526 - val_loss: 0.1152 - val_accuracy: 0.8580
# Epoch 9/25
# 34/34 [==============================] - 2s 49ms/step - loss: 0.1094 - accuracy: 0.9504 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 10/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.1116 - accuracy: 0.9594 - val_loss: 0.1143 - val_accuracy: 0.8693
# Epoch 11/25
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0683 - accuracy: 0.9715 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 12/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9827 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 13/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0411 - accuracy: 0.9852 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 14/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9811 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 15/25
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0527 - accuracy: 0.9804 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 16/25
# 34/34 [==============================] - 2s 67ms/step - loss: 0.0221 - accuracy: 0.9904 - val_loss: 8.5319e-04 - val_accuracy: 1.0000
# Epoch 17/25
# 34/34 [==============================] - 0s 7ms/step - loss: 0.1007 - accuracy: 0.9453 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 18/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0862 - accuracy: 0.9643 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 19/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9877 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 20/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0755 - accuracy: 0.9707 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 21/25
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0490 - accuracy: 0.9792 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 22/25
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 23/25
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0497 - accuracy: 0.9758 - val_loss: 6.8453e-04 - val_accuracy: 1.0000
# Epoch 24/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9931 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 25/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0426 - accuracy: 0.9842 - val_loss: 0.0032 - val_accuracy: 1.0000
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# Epoch 1/25
# 34/34 [==============================] - 4s 72ms/step - loss: 1.7669 - accuracy: 0.4183 - val_loss: 0.7412 - val_accuracy: 0.6493
# Epoch 2/25
# 34/34 [==============================] - 2s 54ms/step - loss: 0.6690 - accuracy: 0.7540 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 3/25
# 34/34 [==============================] - 2s 54ms/step - loss: 0.2876 - accuracy: 0.8993 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 4/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.9478 - val_loss: 0.0489 - val_accuracy: 1.0000
# Epoch 5/25
# 34/34 [==============================] - 2s 68ms/step - loss: 0.2254 - accuracy: 0.9247 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 6/25
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0988 - accuracy: 0.9688 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 7/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0834 - accuracy: 0.9718 - val_loss: 0.4286 - val_accuracy: 0.8753
# Epoch 8/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0521 - accuracy: 0.9822 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 9/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.9805 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 10/25
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0397 - accuracy: 0.9912 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 11/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9978 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 12/25
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 13/25
# 34/34 [==============================] - 2s 65ms/step - loss: 0.0279 - accuracy: 0.9926 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 14/25
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0309 - accuracy: 0.9887 - val_loss: 6.7729e-04 - val_accuracy: 1.0000
# Epoch 15/25
# 34/34 [==============================] - 2s 74ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 1.7770e-04 - val_accuracy: 1.0000
# Epoch 16/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 9.1222e-04 - val_accuracy: 1.0000
# Epoch 17/25
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 5.6435e-04 - val_accuracy: 1.0000
# Epoch 18/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9930 - val_loss: 3.3267e-04 - val_accuracy: 1.0000
# Epoch 19/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 20/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.1086 - accuracy: 0.9596 - val_loss: 0.0385 - val_accuracy: 1.0000
# Epoch 21/25
# 34/34 [==============================] - 2s 65ms/step - loss: 0.0231 - accuracy: 0.9915 - val_loss: 1.0314e-04 - val_accuracy: 1.0000
# Epoch 22/25
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 8.4163e-05 - val_accuracy: 1.0000
# Epoch 23/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 1.1795e-04 - val_accuracy: 1.0000
# Epoch 24/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 2.4255e-04 - val_accuracy: 1.0000
# Epoch 25/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 1.8844e-04 - val_accuracy: 1.0000
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# Epoch 1/25
# 31/34 [==========================>...] - ETA: 0s - loss: 1.2649 - accuracy: 0.5703
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# 34/34 [==============================] - 5s 99ms/step - loss: 1.2231 - accuracy: 0.5848 - val_loss: 0.2479 - val_accuracy: 1.0000
# Epoch 2/25
# 34/34 [==============================] - 2s 65ms/step - loss: 0.3979 - accuracy: 0.8631 - val_loss: 0.1262 - val_accuracy: 1.0000
# Epoch 3/25
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1739 - accuracy: 0.9418 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 4/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0689 - accuracy: 0.9772 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 5/25
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0659 - accuracy: 0.9790 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 6/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9863 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 7/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0386 - accuracy: 0.9862 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 8/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.1005 - accuracy: 0.9654 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 9/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0956 - accuracy: 0.9665 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 10/25
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0661 - accuracy: 0.9807 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 11/25
# 34/34 [==============================] - 3s 81ms/step - loss: 0.0078 - accuracy: 0.9984 - val_loss: 1.4992e-04 - val_accuracy: 1.0000
# Epoch 12/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 2.7520e-04 - val_accuracy: 1.0000
# Epoch 13/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0468 - accuracy: 0.9839 - val_loss: 5.4393e-04 - val_accuracy: 1.0000
# Epoch 14/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 0.9892 - val_loss: 0.2697 - val_accuracy: 0.8807
# Epoch 15/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0761 - accuracy: 0.9755 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 16/25
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 3.0588e-04 - val_accuracy: 1.0000
# Epoch 17/25
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 9.9178e-05 - val_accuracy: 1.0000
# Epoch 18/25
# 34/34 [==============================] - 2s 69ms/step - loss: 3.0767e-04 - accuracy: 1.0000 - val_loss: 3.6297e-06 - val_accuracy: 1.0000
# Epoch 19/25
# 34/34 [==============================] - 2s 58ms/step - loss: 1.6739e-04 - accuracy: 1.0000 - val_loss: 4.8391e-07 - val_accuracy: 1.0000
# Epoch 20/25
# 34/34 [==============================] - 0s 6ms/step - loss: 7.7849e-05 - accuracy: 1.0000 - val_loss: 3.2270e-06 - val_accuracy: 1.0000
# Epoch 21/25
# 34/34 [==============================] - 0s 6ms/step - loss: 5.9892e-05 - accuracy: 1.0000 - val_loss: 4.0316e-06 - val_accuracy: 1.0000
# Epoch 22/25
# 34/34 [==============================] - 0s 6ms/step - loss: 5.0790e-05 - accuracy: 1.0000 - val_loss: 2.3150e-06 - val_accuracy: 1.0000
# Epoch 23/25
# 34/34 [==============================] - 0s 6ms/step - loss: 1.1739e-04 - accuracy: 1.0000 - val_loss: 1.2274e-06 - val_accuracy: 1.0000
# Epoch 24/25
# 34/34 [==============================] - 0s 6ms/step - loss: 9.3446e-05 - accuracy: 1.0000 - val_loss: 9.5669e-07 - val_accuracy: 1.0000
# Epoch 25/25
# 34/34 [==============================] - 0s 6ms/step - loss: 9.9833e-05 - accuracy: 1.0000 - val_loss: 2.8479e-06 - val_accuracy: 1.0000
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 3s 2ms/step

# %%
#Plotting curves for SNR and BLER for different residual level M

plt.figure()
plt.grid(True)
plt.xlim(-4,10)
plt.xlabel('SNR')
plt.ylabel('BLER')
plt.semilogy(SNRs, bers[0], c = 'r', label = 'M=1')
plt.semilogy(SNRs, bers[1], c = 'g', label = 'M=2')
plt.semilogy(SNRs, bers[2], c = 'b', label = 'M=3')
plt.legend(loc='best')
